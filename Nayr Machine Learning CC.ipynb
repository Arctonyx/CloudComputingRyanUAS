# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# %%
data_train = pd.read_csv('/kaggle/input/predicting-blood-analysis/blood-train.csv')
data_test = pd.read_csv('/kaggle/input/predicting-blood-analysis/blood-test.csv')

data_train.head()

# %%
plt.style.use('fivethirtyeight')
sns.barplot(x='Months since Last Donation', y='Made Donation in March 2007', data=data_train)

# %%
sns.pointplot(x='Months since Last Donation', y='Months since First Donation', hue='Made Donation in March 2007', data=data_train)

# %%
data_train['Months since First Donation'].hist(bins=10)

# %%
data_train['Total Volume Donated (c.c.)'].quantile([0, 0.25, 0.75, 0.9])

# %%
def blood_cat(blood):
    if blood < 500.0:
        return 'rendah'
    elif 500.0 <= blood <= 1750.0:
        return 'sedang'
    else:
        return 'tinggi'
    
data_train['Total Volume Donated (c.c.)'] = data_train['Total Volume Donated (c.c.)'].fillna(data_train['Total Volume Donated (c.c.)'].mean())
data_train['BloodCat'] = data_train['Total Volume Donated (c.c.)'].apply(blood_cat)
data_train.head(20)

# %%
sns.barplot(x='BloodCat', y='Made Donation in March 2007', data=data_train)

# %%
sns.factorplot(x='BloodCat', kind='count', hue='Made Donation in March 2007', data=data_train)

# %% [markdown]
# ### Make Predictions

# %%
df_train = pd.read_csv('/kaggle/input/predicting-blood-analysis/blood-train.csv')
df_train.head()
df_test = pd.read_csv('/kaggle/input/predicting-blood-analysis/blood-test.csv')
df_test.head()

# %%
df_train.rename(columns={"Unnamed: 0":"Donor_id"},inplace=True)
df_train.head()
df_test.rename(columns={"Unnamed: 0":"Donor_id"},inplace=True)
df_test.head()

# %%
df_train.shape, df_test.shape

# %%
df_train.info()
print("\n--------------------------------------\n")
df_test.info()

# %%
df_train.describe()

# %%
X_train = df_train.iloc[:,[1,2,3,4]].values
y_train = df_train.iloc[:,-1].values
X_train,y_train

# %%
X_test = df_test.iloc[:,[1,2,3,4]].values
X_test

# %%
Scaler = StandardScaler()
X_train = Scaler.fit_transform(X_train)

X_test = Scaler.fit_transform(X_test)
X_train, X_test

# %% [markdown]
# # Masuk Machine Learning
#
# ### Logistic Regression

# %%
log = LogisticRegression()
log.fit(X_train,y_train)
y_pred = log.predict(X_test)
acc_log = round(classifier.score(X_train,y_train) * 100, 2)
acc_log

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
acc_rf = round(rf.score(X_train,y_train) * 100, 2)
acc_rf

# %% [markdown]
# ### XGBoost

# %%
xg = XGBClassifier()
xg.fit(X_train,y_train)
y_pred = svc.predict(X_test)
acc_xg = round(xg.score(X_train,y_train) * 100, 2)
acc_xg

# %% [markdown]
# ### Support Vector Machine

# %%
svc = SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
acc_svc = round(svc.score(X_train,y_train) * 100, 2)
acc_svc

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
acc_knn = round(knn.score(X_train,y_train) * 100, 2)
acc_knn

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
Gaussian = GaussianNB()
Gaussian.fit(X_train,y_train)
y_pred = Gaussian.predict(X_test)
acc_Gaussian = round(Gaussian.score(X_train,y_train) * 100, 2)
acc_Gaussian

# %% [markdown]
# ### Perceptron

# %%
perceptron = Perceptron()
perceptron.fit(X_train,y_train)
y_pred = perceptron.predict(X_test)
acc_perceptron = round(perceptron.score(X_train,y_train) * 100, 2)
acc_perceptron

# %% [markdown]
# ### Linear SVC

# %%
linear_svc = LinearSVC ()
linear_svc.fit(X_train,y_train)
y_pred = linear_svc.predict(X_test)
acc_linear_svc = round(linear_svc.score(X_train,y_train) * 100, 2)
acc_linear_svc

# %% [markdown]
# ### Stochastic Gradient Desent

# %%
sgd = SGDClassifier()
sgd.fit(X_train,y_train)
y_pred = sgd.predict(X_test)
acc_sgd = round(sgd.score(X_train,y_train) * 100, 2)
acc_sgd

# %% [markdown]
# ### Decision Tree

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train,y_train)
y_pred = tree.predict(X_test)
acc_tree = round(tree.score(X_train,y_train) * 100, 2)
acc_tree

# %%
models = pd.DataFrame({
    'Model' : ['logistic Regression','Random Forest','XGBoost','SVC','KNN','Gaussian','Perceptron','Linear SVC','SGD','Tree'],
    'Score' : [acc_log, acc_rf, acc_xg, acc_svc, acc_knn, acc_Gaussian, acc_perceptron, acc_linear_svc, acc_sgd, acc_tree]
})
models.sort_values(by='Score', ascending=False)

# %%
df_test['#Tree'] = y_pred
df_test

# %%
df_test.to_csv('result_tree.csv', index=False)
